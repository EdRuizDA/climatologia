# %% [markdown]
# <a href="https://colab.research.google.com/github/EdRuizDA/climatologia/blob/main/Analisis_DeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Librerias

# %%
#Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels as sm
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #  1.-SMN Dataset

# %% [markdown]
# ## Paths y Dataframes

# %%
#Paths Estaciones Climatologicas SMN
smnpath30071 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroSMN/dia30071.csv'
smnpath30160 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroSMN/dia30160.csv'
smnpath30169 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroSMN/dia30169.csv'
smnpath30220 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroSMN/dia30220.csv'
smnpath30304 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroSMN/dia30304.csv'
smnpath30325 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroSMN/dia30325.csv'
smnpath30345 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroSMN/dia30345.csv'

# %%
#DataFrames Estaciones Climatologicas SMN
df_30071smn = pd.read_csv(smnpath30071)
df_30160smn = pd.read_csv(smnpath30160)
df_30169smn = pd.read_csv(smnpath30169)
df_30220smn = pd.read_csv(smnpath30220)
df_30304smn = pd.read_csv(smnpath30304)
df_30325smn = pd.read_csv(smnpath30325)
df_30345smn = pd.read_csv(smnpath30345)

# %%
df_30071smn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16801 entries, 0 to 16800
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dia      16801 non-null  int64
#  1   mes      16801 non-null  int64
#  2   year     16801 non-null  int64
#  3   pcp_mm   16801 non-null  object
#  4   evap_mm  16801 non-null  object
#  5   tmax_C   16801 non-null  object
#  6   tmin_C   16801 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 918.9+ KB

# %% [markdown]
# ## Datetime

# %%
df_30071smn['fecha'] = pd.to_datetime(df_30071smn['year'].astype(str) + '-' + df_30071smn['mes'].astype(str) + '-' + df_30071smn['dia'].astype(str), format='%Y-%m-%d')
df_30160smn['fecha'] = pd.to_datetime(df_30160smn['year'].astype(str) + '-' + df_30160smn['mes'].astype(str) + '-' + df_30160smn['dia'].astype(str), format='%Y-%m-%d')
df_30169smn['fecha'] = pd.to_datetime(df_30169smn['year'].astype(str) + '-' + df_30169smn['mes'].astype(str) + '-' + df_30169smn['dia'].astype(str), format='%Y-%m-%d')
df_30220smn['fecha'] = pd.to_datetime(df_30220smn['year'].astype(str) + '-' + df_30220smn['mes'].astype(str) + '-' + df_30220smn['dia'].astype(str), format='%Y-%m-%d')
df_30304smn['fecha'] = pd.to_datetime(df_30304smn['year'].astype(str) + '-' + df_30304smn['mes'].astype(str) + '-' + df_30304smn['dia'].astype(str), format='%Y-%m-%d')
df_30325smn['fecha'] = pd.to_datetime(df_30325smn['year'].astype(str) + '-' + df_30325smn['mes'].astype(str) + '-' + df_30325smn['dia'].astype(str), format='%Y-%m-%d')
df_30345smn['fecha'] = pd.to_datetime(df_30345smn['year'].astype(str) + '-' + df_30345smn['mes'].astype(str) + '-' + df_30345smn['dia'].astype(str), format='%Y-%m-%d')

# %%
df_30345smn.head()
# Out:
#    dia  mes  year pcp_mm evap_mm tmax_C tmin_C      fecha
# 0    1    1  1979      0     1.3     21   13.5 1979-01-01
# 1    2    1  1979    0.5     1.3     23     13 1979-01-02
# 2    3    1  1979      3     0.4     24   16.5 1979-01-03
# 3    4    1  1979      0     1.3     21   10.5 1979-01-04
# 4    5    1  1979      0     1.8   23.5      9 1979-01-05

# %%
#Colocando la columna 'año_mes'
df_30071smn['año_mes'] = df_30071smn['fecha'].dt.to_period('M')
df_30160smn['año_mes'] = df_30160smn['fecha'].dt.to_period('M')
df_30169smn['año_mes'] = df_30169smn['fecha'].dt.to_period('M')
df_30220smn['año_mes'] = df_30220smn['fecha'].dt.to_period('M')
df_30304smn['año_mes'] = df_30304smn['fecha'].dt.to_period('M')
df_30325smn['año_mes'] = df_30325smn['fecha'].dt.to_period('M')
df_30345smn['año_mes'] = df_30345smn['fecha'].dt.to_period('M')

# %% [markdown]
# ## Datos faltantes

# %%
#Cambio de pcp_mm de 'objet' a 'float'
df_30071smn['pcp_mm'] = pd.to_numeric(df_30071smn['pcp_mm'], errors='coerce')
df_30160smn['pcp_mm'] = pd.to_numeric(df_30160smn['pcp_mm'], errors='coerce')
df_30169smn['pcp_mm'] = pd.to_numeric(df_30169smn['pcp_mm'], errors='coerce')
df_30220smn['pcp_mm'] = pd.to_numeric(df_30220smn['pcp_mm'], errors='coerce')
df_30304smn['pcp_mm'] = pd.to_numeric(df_30304smn['pcp_mm'], errors='coerce')
df_30325smn['pcp_mm'] = pd.to_numeric(df_30325smn['pcp_mm'], errors='coerce')
df_30345smn['pcp_mm'] = pd.to_numeric(df_30345smn['pcp_mm'], errors='coerce')

# %%
df_30345smn.head()
# Out:
#    dia  mes  year  pcp_mm evap_mm tmax_C tmin_C      fecha  año_mes
# 0    1    1  1979     0.0     1.3     21   13.5 1979-01-01  1979-01
# 1    2    1  1979     0.5     1.3     23     13 1979-01-02  1979-01
# 2    3    1  1979     3.0     0.4     24   16.5 1979-01-03  1979-01
# 3    4    1  1979     0.0     1.3     21   10.5 1979-01-04  1979-01
# 4    5    1  1979     0.0     1.8   23.5      9 1979-01-05  1979-01

# %%
df_30345smn.iloc[4903:4915,0:4]
# Out:
#       dia  mes  year  pcp_mm
# 4903   30   12  1993     6.5
# 4904   31   12  1993     0.0
# 4905    1    1  1994     0.5
# 4906    2    1  1994     0.0
# 4907    3    1  1994     0.0
# 4908    4    1  1994     0.0
# 4909    5    1  1994     0.0
# 4910    6    1  1994     0.0
# 4911    7    1  1994     0.0
# 4912    8    1  1994     0.0
# 4913    9    1  1994     0.0
# 4914   10    1  1994     0.0

# %%
df_30071smn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16801 entries, 0 to 16800
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dia      16801 non-null  int64
#  1   mes      16801 non-null  int64
#  2   year     16801 non-null  int64
#  3   pcp_mm   16796 non-null  float64
#  4   evap_mm  16801 non-null  object
#  5   tmax_C   16801 non-null  object
#  6   tmin_C   16801 non-null  object
#  7   fecha    16801 non-null  datetime64[ns]
#  8   año_mes  16801 non-null  period[M]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3), period[M](1)
# memory usage: 1.2+ MB

# %%
#Dias de registro
df_30071smnd = df_30071smn.groupby(['año_mes'])['pcp_mm'].count().reset_index()
df_30160smnd = df_30160smn.groupby(['año_mes'])['pcp_mm'].count().reset_index()
df_30169smnd = df_30169smn.groupby(['año_mes'])['pcp_mm'].count().reset_index()
df_30220smnd = df_30220smn.groupby(['año_mes'])['pcp_mm'].count().reset_index()
df_30304smnd = df_30304smn.groupby(['año_mes'])['pcp_mm'].count().reset_index()
df_30325smnd = df_30325smn.groupby(['año_mes'])['pcp_mm'].count().reset_index()
df_30345smnd = df_30345smn.groupby(['año_mes'])['pcp_mm'].count().reset_index()

# %%
df_30345smnd.iloc[160:170,0:3]
# Out:
#      año_mes  pcp_mm
# 160  1993-11      30
# 161  1993-12      31
# 162  1994-01      31
# 163  1994-02      28
# 164  1994-03      31
# 165  1994-04      30
# 166  1994-05      31
# 167  1994-06      30
# 168  1994-07      31
# 169  1994-08      31

# %%
#Cambiando nombre a los dias de registro
df_30071smnd.rename(columns={'pcp_mm':'diasreg'},inplace=True)
df_30160smnd.rename(columns={'pcp_mm':'diasreg'},inplace=True)
df_30169smnd.rename(columns={'pcp_mm':'diasreg'},inplace=True)
df_30220smnd.rename(columns={'pcp_mm':'diasreg'},inplace=True)
df_30304smnd.rename(columns={'pcp_mm':'diasreg'},inplace=True)
df_30325smnd.rename(columns={'pcp_mm':'diasreg'},inplace=True)
df_30345smnd.rename(columns={'pcp_mm':'diasreg'},inplace=True)

# %%
df_30071smnd.head()
# Out:
#    año_mes  diasreg
# 0  1961-01       31
# 1  1961-02       28
# 2  1961-03       31
# 3  1961-04       30
# 4  1961-05       31

# %% [markdown]
# ## Agrupando PCP por mes

# %%
#Precipitacion mensual
df_30071smnNN=df_30071smn.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30160smnNN=df_30160smn.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30169smnNN=df_30169smn.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30220smnNN=df_30220smn.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30304smnNN=df_30304smn.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30325smnNN=df_30325smn.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30345smnNN=df_30345smn.groupby(['año_mes'])['pcp_mm'].sum().reset_index()

# %%
df_30071smnNN.head()
# Out:
#    año_mes  pcp_mm
# 0  1961-01    89.5
# 1  1961-02    25.0
# 2  1961-03    21.5
# 3  1961-04     1.0
# 4  1961-05    17.5

# %%
#Haciendo merge de Dataframes
df_30071smnN = pd.merge(df_30071smnd,df_30071smnNN, on='año_mes', how='outer')
df_30160smnN = pd.merge(df_30160smnd,df_30160smnNN, on='año_mes', how='outer')
df_30169smnN = pd.merge(df_30169smnd,df_30169smnNN, on='año_mes', how='outer')
df_30220smnN = pd.merge(df_30220smnd,df_30220smnNN, on='año_mes', how='outer')
df_30304smnN = pd.merge(df_30304smnd,df_30304smnNN, on='año_mes', how='outer')
df_30325smnN = pd.merge(df_30325smnd,df_30325smnNN, on='año_mes', how='outer')
df_30345smnN = pd.merge(df_30345smnd,df_30345smnNN, on='año_mes', how='outer')

# %%
df_30345smnN.iloc[160:170,0:3]
# Out:
#      año_mes  diasreg  pcp_mm
# 160  1993-11       30   130.0
# 161  1993-12       31    21.0
# 162  1994-01       31    44.5
# 163  1994-02       28    42.5
# 164  1994-03       31     8.5
# 165  1994-04       30    75.5
# 166  1994-05       31     8.0
# 167  1994-06       30   128.5
# 168  1994-07       31     9.5
# 169  1994-08       31   332.5

# %%
df_30071smnN.head(15)
# Out:
#     año_mes  diasreg  pcp_mm
# 0   1961-01       31    89.5
# 1   1961-02       28    25.0
# 2   1961-03       31    21.5
# 3   1961-04       30     1.0
# 4   1961-05       31    17.5
# 5   1961-06       30   331.0
# 6   1961-07       31   228.5
# 7   1961-08       31   115.0
# 8   1961-09       30   234.0
# 9   1961-10       31   127.0
# 10  1961-11       30   184.0
# 11  1961-12       31    16.0
# 12  1962-01       31     5.0
# 13  1962-02       28     7.0
# 14  1962-03       31    49.0

# %% [markdown]
# ## Dataframe to csv

# %%
path30071smnN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/1.SMN/30071smn.csv'
path30160smnN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/1.SMN/30160smn.csv'
path30169smnN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/1.SMN/30169smn.csv'
path30220smnN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/1.SMN/30220smn.csv'
path30304smnN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/1.SMN/30304smn.csv'
path30325smnN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/1.SMN/30325smn.csv'
path30345smnN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/1.SMN/30345smn.csv'

# %%
#Exportando to CSV
df_30071smnN.to_csv(path30071smnN,index=False)
df_30160smnN.to_csv(path30160smnN,index=False)
df_30169smnN.to_csv(path30169smnN,index=False)
df_30220smnN.to_csv(path30220smnN,index=False)
df_30304smnN.to_csv(path30304smnN,index=False)
df_30325smnN.to_csv(path30325smnN,index=False)
df_30345smnN.to_csv(path30345smnN,index=False)

# %% [markdown]
# # 2.-Power-NASA Dataset

# %% [markdown]
# ## Paths y Dataframes

# %%
#Paths Estaciones Climatologicas Power-NASA
pwpath30071 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroPowerNASA/POWER_Est_30071.csv'
pwpath30160 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroPowerNASA/POWER_Est_30160.csv'
pwpath30169 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroPowerNASA/POWER_Est_30169.csv'
pwpath30220 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroPowerNASA/POWER_Est_30220.csv'
pwpath30304 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroPowerNASA/POWER_Est_30304.csv'
pwpath30325 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroPowerNASA/POWER_Est_30325.csv'
pwpath30345 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroPowerNASA/POWER_Est_30345.csv'

# %%
#DataFrames Estaciones Climatologicas Power-NASA
df_30071pw = pd.read_csv(pwpath30071)
df_30160pw = pd.read_csv(pwpath30160)
df_30169pw = pd.read_csv(pwpath30169)
df_30220pw = pd.read_csv(pwpath30220)
df_30304pw = pd.read_csv(pwpath30304)
df_30325pw = pd.read_csv(pwpath30325)
df_30345pw = pd.read_csv(pwpath30345)

# %%
df_30071pw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15705 entries, 0 to 15704
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       15705 non-null  int64
#  1   day        15705 non-null  int64
#  2   pcp_mmdia  15705 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 368.2 KB

# %%
df_30071pw.head(5)
# Out:
#    year  day  pcp_mmdia
# 0  1981    1       0.27
# 1  1981    2       0.05
# 2  1981    3       0.00
# 3  1981    4       0.15
# 4  1981    5       0.10

# %% [markdown]
# ## Datetime

# %%
#df['fecha'] = pd.to_datetime(df['año'].astype(str) + '-' + df['dia'].astype(str), format='%Y-%d')

# %%
#Agrupando por año y dia
df_30071pw['fecha'] = pd.to_datetime(df_30071pw['year'].astype(str) + '-' + df_30071pw['day'].astype(str), format = '%Y-%j')
df_30160pw['fecha'] = pd.to_datetime(df_30160pw['year'].astype(str) + '-' + df_30160pw['day'].astype(str), format = '%Y-%j')
df_30169pw['fecha'] = pd.to_datetime(df_30169pw['year'].astype(str) + '-' + df_30169pw['day'].astype(str), format = '%Y-%j')
df_30220pw['fecha'] = pd.to_datetime(df_30220pw['year'].astype(str) + '-' + df_30220pw['day'].astype(str), format = '%Y-%j')
df_30304pw['fecha'] = pd.to_datetime(df_30304pw['year'].astype(str) + '-' + df_30304pw['day'].astype(str), format = '%Y-%j')
df_30325pw['fecha'] = pd.to_datetime(df_30325pw['year'].astype(str) + '-' + df_30325pw['day'].astype(str), format = '%Y-%j')
df_30345pw['fecha'] = pd.to_datetime(df_30345pw['year'].astype(str) + '-' + df_30345pw['day'].astype(str), format = '%Y-%j')

# %% [markdown]
# ## Agrupando PCP por mes

# %%
#Creando un nuevo dataframe
df_30071pwN = df_30071pw.groupby(df_30071pw['fecha'].dt.to_period('M'))['pcp_mmdia'].sum().reset_index()
df_30160pwN = df_30160pw.groupby(df_30160pw['fecha'].dt.to_period('M'))['pcp_mmdia'].sum().reset_index()
df_30169pwN = df_30169pw.groupby(df_30169pw['fecha'].dt.to_period('M'))['pcp_mmdia'].sum().reset_index()
df_30220pwN = df_30220pw.groupby(df_30220pw['fecha'].dt.to_period('M'))['pcp_mmdia'].sum().reset_index()
df_30304pwN = df_30304pw.groupby(df_30304pw['fecha'].dt.to_period('M'))['pcp_mmdia'].sum().reset_index()
df_30325pwN = df_30325pw.groupby(df_30325pw['fecha'].dt.to_period('M'))['pcp_mmdia'].sum().reset_index()
df_30345pwN = df_30345pw.groupby(df_30345pw['fecha'].dt.to_period('M'))['pcp_mmdia'].sum().reset_index()

# %%
df_30071pwN.head()
# Out:
#      fecha  pcp_mmdia
# 0  1981-01     115.90
# 1  1981-02      71.63
# 2  1981-03      49.86
# 3  1981-04     110.55
# 4  1981-05     147.01

# %%
#Cambiando nombre de la columba pcp
df_30071pwN.rename(columns={'pcp_mmdia':'pcp_mm'},inplace=True)
df_30160pwN.rename(columns={'pcp_mmdia':'pcp_mm'},inplace=True)
df_30169pwN.rename(columns={'pcp_mmdia':'pcp_mm'},inplace=True)
df_30220pwN.rename(columns={'pcp_mmdia':'pcp_mm'},inplace=True)
df_30304pwN.rename(columns={'pcp_mmdia':'pcp_mm'},inplace=True)
df_30325pwN.rename(columns={'pcp_mmdia':'pcp_mm'},inplace=True)
df_30345pwN.rename(columns={'pcp_mmdia':'pcp_mm'},inplace=True)

# %%
df_30071pwN.head()
# Out:
#      fecha  pcp_mm
# 0  1981-01  115.90
# 1  1981-02   71.63
# 2  1981-03   49.86
# 3  1981-04  110.55
# 4  1981-05  147.01

# %% [markdown]
# ## Dataframe to csv

# %%
#Paths
path30071pwN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/2.POWERNASA/30071pwN.csv'
path30160pwN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/2.POWERNASA/30160pwN.csv'
path30169pwN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/2.POWERNASA/30169pwN.csv'
path30220pwN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/2.POWERNASA/30220pwN.csv'
path30304pwN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/2.POWERNASA/30304pwN.csv'
path30325pwN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/2.POWERNASA/30325pwN.csv'
path30345pwN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/2.POWERNASA/30345pwN.csv'

# %%
#Exportando a csv
df_30071pwN.to_csv(path30071pwN, index=False)
df_30160pwN.to_csv(path30160pwN, index=False)
df_30169pwN.to_csv(path30169pwN, index=False)
df_30220pwN.to_csv(path30220pwN, index=False)
df_30304pwN.to_csv(path30304pwN, index=False)
df_30325pwN.to_csv(path30325pwN, index=False)
df_30345pwN.to_csv(path30345pwN, index=False)

# %% [markdown]
# # 3.-IMERG-NASA Dataset

# %% [markdown]
# ## Paths y Dataframes

# %%
#Paths Estaciones Climatologicas IMERG-NASA
gpmpath30071 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroIMERGNASA/Estacion_30071_rmean.csv'
gpmpath30160 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroIMERGNASA/Estacion_30160_rmean.csv'
gpmpath30169 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroIMERGNASA/Estacion_30169_rmean.csv'
gpmpath30220 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroIMERGNASA/Estacion_30220_rmean.csv'
gpmpath30304 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroIMERGNASA/Estacion_30304_rmean.csv'
gpmpath30325 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroIMERGNASA/Estacion_30325_rmean.csv'
gpmpath30345 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroIMERGNASA/Estacion_30345_rmean.csv'

# %%
#DataFrames Estaciones Climatologicas IMERG-NASA
df_30071gpm = pd.read_csv(gpmpath30071)
df_30160gpm = pd.read_csv(gpmpath30160)
df_30169gpm = pd.read_csv(gpmpath30169)
df_30220gpm = pd.read_csv(gpmpath30220)
df_30304gpm = pd.read_csv(gpmpath30304)
df_30325gpm = pd.read_csv(gpmpath30325)
df_30345gpm = pd.read_csv(gpmpath30345)

# %%
df_30071gpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413422 entries, 0 to 413421
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   fecha   413422 non-null  object
#  1   pcp     413422 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 6.3+ MB

# %%
df_30071gpm.head(15)
# Out:
#                  fecha  pcp
# 0  2000-06-01 00:00:00  0.0
# 1  2000-06-01 00:30:00  0.0
# 2  2000-06-01 01:00:00  0.0
# 3  2000-06-01 01:30:00  0.0
# 4  2000-06-01 02:00:00  0.0
# 5  2000-06-01 02:30:00  0.0
# 6  2000-06-01 03:00:00  0.0
# 7  2000-06-01 03:30:00  0.0
# 8  2000-06-01 04:00:00  0.0
# 9  2000-06-01 04:30:00  0.0
# 10 2000-06-01 05:00:00  0.0
# 11 2000-06-01 05:30:00  0.0
# 12 2000-06-01 06:00:00  0.0
# 13 2000-06-01 06:30:00  0.0
# 14 2000-06-01 07:00:00  0.0

# %% [markdown]
# ## Datetime

# %%
df_30071gpm['fecha'] = pd.to_datetime(df_30071gpm['fecha'])
df_30160gpm['fecha'] = pd.to_datetime(df_30160gpm['fecha'])
df_30169gpm['fecha'] = pd.to_datetime(df_30169gpm['fecha'])
df_30220gpm['fecha'] = pd.to_datetime(df_30220gpm['fecha'])
df_30304gpm['fecha'] = pd.to_datetime(df_30304gpm['fecha'])
df_30325gpm['fecha'] = pd.to_datetime(df_30325gpm['fecha'])
df_30345gpm['fecha'] = pd.to_datetime(df_30345gpm['fecha'])

# %%
df_30071gpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413422 entries, 0 to 413421
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   fecha   413422 non-null  datetime64[ns]
#  1   pcp     413422 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.3 MB

# %% [markdown]
# ## Agrupando PCP por mes

# %%
#Agregando una columna año_mes
df_30071gpm['año_mes']=df_30071gpm['fecha'].dt.to_period('M')
df_30160gpm['año_mes']=df_30160gpm['fecha'].dt.to_period('M')
df_30169gpm['año_mes']=df_30169gpm['fecha'].dt.to_period('M')
df_30220gpm['año_mes']=df_30220gpm['fecha'].dt.to_period('M')
df_30304gpm['año_mes']=df_30304gpm['fecha'].dt.to_period('M')
df_30325gpm['año_mes']=df_30325gpm['fecha'].dt.to_period('M')
df_30345gpm['año_mes']=df_30345gpm['fecha'].dt.to_period('M')

# %%
#Agrupando la pcp por mes
df_30071gpmN = df_30071gpm.groupby('año_mes')['pcp'].sum().reset_index()
df_30160gpmN = df_30160gpm.groupby('año_mes')['pcp'].sum().reset_index()
df_30169gpmN = df_30169gpm.groupby('año_mes')['pcp'].sum().reset_index()
df_30220gpmN = df_30220gpm.groupby('año_mes')['pcp'].sum().reset_index()
df_30304gpmN = df_30304gpm.groupby('año_mes')['pcp'].sum().reset_index()
df_30325gpmN = df_30325gpm.groupby('año_mes')['pcp'].sum().reset_index()
df_30345gpmN = df_30345gpm.groupby('año_mes')['pcp'].sum().reset_index()

# %%
df_30071gpmN.head()
# Out:
#    año_mes         pcp
# 0  2000-06  591.808227
# 1  2000-07  137.267903
# 2  2000-08  432.166191
# 3  2000-09  267.510631
# 4  2000-10  184.493617

# %%
#Colocando unidades a la columna de pcp
df_30071gpmN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30160gpmN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30169gpmN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30220gpmN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30304gpmN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30325gpmN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30345gpmN.rename(columns={'pcp':'pcp_mm'},inplace=True)

# %% [markdown]
# ## Dataframe to csv

# %%
#Paths donde guardar los csv
path30071gpmN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/3.IMERGNASA/30071gpmN.csv'
path30160gpmN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/3.IMERGNASA/30160gpmN.csv'
path30169gpmN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/3.IMERGNASA/30169gpmN.csv'
path30220gpmN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/3.IMERGNASA/30220gpmN.csv'
path30304gpmN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/3.IMERGNASA/30304gpmN.csv'
path30325gpmN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/3.IMERGNASA/30325gpmN.csv'
path30345gpmN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/3.IMERGNASA/30345gpmN.csv'

# %%
#Exportando a csv
df_30071gpmN.to_csv(path30071gpmN,index=False)
df_30160gpmN.to_csv(path30160gpmN,index=False)
df_30169gpmN.to_csv(path30169gpmN,index=False)
df_30220gpmN.to_csv(path30220gpmN,index=False)
df_30304gpmN.to_csv(path30304gpmN,index=False)
df_30325gpmN.to_csv(path30325gpmN,index=False)
df_30345gpmN.to_csv(path30345gpmN,index=False)

# %% [markdown]
# # 4.-CHIRPS Dataset

# %% [markdown]
# ## Paths y Dataframes

# %%
#Paths Estaciones Climatologicas CHIRPS
chpath30071 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroCHIRPS/Estacion_30071_rmeanCh.csv'
chpath30160 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroCHIRPS/Estacion_30160_rmeanCh.csv'
chpath30169 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroCHIRPS/Estacion_30169_rmeanCh.csv'
chpath30220 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroCHIRPS/Estacion_30220_rmeanCh.csv'
chpath30304 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroCHIRPS/Estacion_30304_rmeanCh.csv'
chpath30325 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroCHIRPS/Estacion_30325_rmeanCh.csv'
chpath30345 = '/content/drive/MyDrive/Climatologia_SeriesDeTiempo/EstDentroCHIRPS/Estacion_30345_rmeanCh.csv'

# %%
#DataFrames Estaciones Climatologicas CHIRPS
df_30071ch = pd.read_csv(chpath30071)
df_30160ch = pd.read_csv(chpath30160)
df_30169ch = pd.read_csv(chpath30169)
df_30220ch = pd.read_csv(chpath30220)
df_30304ch = pd.read_csv(chpath30304)
df_30325ch = pd.read_csv(chpath30325)
df_30345ch = pd.read_csv(chpath30345)

# %% [markdown]
# ## Datetime

# %%
df_30071ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15704 entries, 0 to 15703
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   15704 non-null  object
#  1   pcp     15704 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 245.5+ KB

# %%
df_30071ch['fecha'] = pd.to_datetime(df_30071ch['fecha'])
df_30160ch['fecha'] = pd.to_datetime(df_30160ch['fecha'])
df_30169ch['fecha'] = pd.to_datetime(df_30169ch['fecha'])
df_30220ch['fecha'] = pd.to_datetime(df_30220ch['fecha'])
df_30304ch['fecha'] = pd.to_datetime(df_30304ch['fecha'])
df_30325ch['fecha'] = pd.to_datetime(df_30325ch['fecha'])
df_30345ch['fecha'] = pd.to_datetime(df_30345ch['fecha'])

# %%
df_30304ch.head()
# Out:
#        fecha  pcp
# 0 1981-01-01  0.0
# 1 1981-01-02  0.0
# 2 1981-01-03  0.0
# 3 1981-01-04  0.0
# 4 1981-01-05  0.0

# %% [markdown]
# ## Agrupando PCP por mes

# %%
#Agregando la columna año_mes
df_30071ch['año_mes'] = df_30071ch['fecha'].dt.to_period('M')
df_30160ch['año_mes'] = df_30160ch['fecha'].dt.to_period('M')
df_30169ch['año_mes'] = df_30169ch['fecha'].dt.to_period('M')
df_30220ch['año_mes'] = df_30220ch['fecha'].dt.to_period('M')
df_30304ch['año_mes'] = df_30304ch['fecha'].dt.to_period('M')
df_30325ch['año_mes'] = df_30325ch['fecha'].dt.to_period('M')
df_30345ch['año_mes'] = df_30345ch['fecha'].dt.to_period('M')

# %%
#Nuevo dateframe agrupando la precipitacion por mes
df_30071chN = df_30071ch.groupby('año_mes')['pcp'].sum().reset_index()
df_30160chN = df_30160ch.groupby('año_mes')['pcp'].sum().reset_index()
df_30169chN = df_30169ch.groupby('año_mes')['pcp'].sum().reset_index()
df_30220chN = df_30220ch.groupby('año_mes')['pcp'].sum().reset_index()
df_30304chN = df_30304ch.groupby('año_mes')['pcp'].sum().reset_index()
df_30325chN = df_30325ch.groupby('año_mes')['pcp'].sum().reset_index()
df_30345chN = df_30345ch.groupby('año_mes')['pcp'].sum().reset_index()

# %%
df_30071chN.head()
# Out:
#    año_mes         pcp
# 0  1981-01   98.341476
# 1  1981-02   51.269135
# 2  1981-03   34.311340
# 3  1981-04   89.639247
# 4  1981-05  143.869697

# %%
#Colocacion de unidades a la columna de pcp
df_30071chN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30160chN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30169chN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30220chN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30304chN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30325chN.rename(columns={'pcp':'pcp_mm'},inplace=True)
df_30345chN.rename(columns={'pcp':'pcp_mm'},inplace=True)

# %% [markdown]
# ## Dataframe to csv

# %%
#paths donde se guardaran los csv
path30071chN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/4.CHIRPS/30071chN.csv'
path30160chN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/4.CHIRPS/30160chN.csv'
path30169chN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/4.CHIRPS/30169chN.csv'
path30220chN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/4.CHIRPS/30220chN.csv'
path30304chN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/4.CHIRPS/30304chN.csv'
path30325chN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/4.CHIRPS/30325chN.csv'
path30345chN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/4.CHIRPS/30345chN.csv'

# %%
#Exportando a csv
df_30071chN.to_csv(path30071chN,index=False)
df_30160chN.to_csv(path30160chN,index=False)
df_30169chN.to_csv(path30169chN,index=False)
df_30220chN.to_csv(path30220chN,index=False)
df_30304chN.to_csv(path30304chN,index=False)
df_30325chN.to_csv(path30325chN,index=False)
df_30345chN.to_csv(path30345chN,index=False)

# %% [markdown]
# # 5.-Copernicus Dataset

# %% [markdown]
# ## 5.1.-ERA5-Land Hourly Dataset

# %% [markdown]
# ### Paths y Dataframes

# %%
#Paths Estaciones Climatologicas ERA5
era5lhpath30071 = '/content/drive/MyDrive/ERA5LandHourly_Est_Dentro/Estacion_30071_era5LH.csv'
era5lhpath30160 = '/content/drive/MyDrive/ERA5LandHourly_Est_Dentro/Estacion_30160_era5LH.csv'
era5lhpath30169 = '/content/drive/MyDrive/ERA5LandHourly_Est_Dentro/Estacion_30169_era5LH.csv'
era5lhpath30220 = '/content/drive/MyDrive/ERA5LandHourly_Est_Dentro/Estacion_30220_era5LH.csv'
era5lhpath30304 = '/content/drive/MyDrive/ERA5LandHourly_Est_Dentro/Estacion_30304_era5LH.csv'
era5lhpath30325 = '/content/drive/MyDrive/ERA5LandHourly_Est_Dentro/Estacion_30325_era5LH.csv'
era5lhpath30345 = '/content/drive/MyDrive/ERA5LandHourly_Est_Dentro/Estacion_30345_era5LH.csv'

# %%
#Dataframes
df_30071era5lh = pd.read_csv(era5lhpath30071)
df_30160era5lh = pd.read_csv(era5lhpath30160)
df_30169era5lh = pd.read_csv(era5lhpath30169)
df_30220era5lh = pd.read_csv(era5lhpath30220)
df_30304era5lh = pd.read_csv(era5lhpath30304)
df_30325era5lh = pd.read_csv(era5lhpath30325)
df_30345era5lh = pd.read_csv(era5lhpath30345)

# %%
df_30071era5lh.head()
# Out:
#               fecha     pcp_m
# 0  1981-01-01 00:00  0.000015
# 1  1981-01-01 01:00  0.000000
# 2  1981-01-01 02:00  0.000000
# 3  1981-01-01 03:00  0.000000
# 4  1981-01-01 04:00  0.000000

# %% [markdown]
# ### Datetime

# %%
df_30071era5lh['fecha'] = pd.to_datetime(df_30071era5lh['fecha'])
df_30160era5lh['fecha'] = pd.to_datetime(df_30160era5lh['fecha'])
df_30169era5lh['fecha'] = pd.to_datetime(df_30169era5lh['fecha'])
df_30220era5lh['fecha'] = pd.to_datetime(df_30220era5lh['fecha'])
df_30304era5lh['fecha'] = pd.to_datetime(df_30304era5lh['fecha'])
df_30325era5lh['fecha'] = pd.to_datetime(df_30325era5lh['fecha'])
df_30345era5lh['fecha'] = pd.to_datetime(df_30345era5lh['fecha'])

# %%
df_30071era5lh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376896 entries, 0 to 376895
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   fecha   376896 non-null  datetime64[ns]
#  1   pcp_m   376896 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.8 MB

# %% [markdown]
# ### Agrupando PCP por mes

# %%
df_30071era5lh['año_mes'] = df_30071ch['fecha'].dt.to_period('M')
df_30160era5lh['año_mes'] = df_30160ch['fecha'].dt.to_period('M')
df_30169era5lh['año_mes'] = df_30169ch['fecha'].dt.to_period('M')
df_30220era5lh['año_mes'] = df_30220ch['fecha'].dt.to_period('M')
df_30304era5lh['año_mes'] = df_30304ch['fecha'].dt.to_period('M')
df_30325era5lh['año_mes'] = df_30325ch['fecha'].dt.to_period('M')
df_30345era5lh['año_mes'] = df_30345ch['fecha'].dt.to_period('M')

# %%
df_30169era5lh.head()
# Out:
#                 fecha       pcp  año_mes
# 0 1981-01-01 00:00:00  0.000018  1981-01
# 1 1981-01-01 01:00:00  0.000000  1981-01
# 2 1981-01-01 02:00:00  0.000000  1981-01
# 3 1981-01-01 03:00:00  0.000000  1981-01
# 4 1981-01-01 04:00:00  0.000000  1981-01

# %%
#Poniendo la pcp en mm
df_30071era5lh['pcp_mm'] = df_30071era5lh['pcp_m']*1000
df_30160era5lh['pcp_mm'] = df_30160era5lh['pcp_m']*1000
df_30169era5lh['pcp_mm'] = df_30169era5lh['pcp']*1000
df_30220era5lh['pcp_mm'] = df_30220era5lh['pcp_m']*1000
df_30304era5lh['pcp_mm'] = df_30304era5lh['pcp_m']*1000
df_30325era5lh['pcp_mm'] = df_30325era5lh['pcp_m']*1000
df_30345era5lh['pcp_mm'] = df_30345era5lh['pcp']*1000

# %%
df_30071era5lh.head()
# Out:
#                 fecha     pcp_m  año_mes    pcp_mm
# 0 1981-01-01 00:00:00  0.000015  1981-01  0.015476
# 1 1981-01-01 01:00:00  0.000000  1981-01  0.000000
# 2 1981-01-01 02:00:00  0.000000  1981-01  0.000000
# 3 1981-01-01 03:00:00  0.000000  1981-01  0.000000
# 4 1981-01-01 04:00:00  0.000000  1981-01  0.000000

# %%
#Agrupando por PCP
df_30071era5lhN = df_30071era5lh.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30160era5lhN = df_30160era5lh.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30169era5lhN = df_30169era5lh.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30220era5lhN = df_30220era5lh.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30304era5lhN = df_30304era5lh.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30325era5lhN = df_30325era5lh.groupby(['año_mes'])['pcp_mm'].sum().reset_index()
df_30345era5lhN = df_30345era5lh.groupby(['año_mes'])['pcp_mm'].sum().reset_index()

# %%
df_30071era5lhN.head()
# Out:
#    año_mes     pcp_mm
# 0  1981-01   0.091271
# 1  1981-02   1.053560
# 2  1981-03   0.131431
# 3  1981-04  10.736495
# 4  1981-05   5.689259

# %% [markdown]
# ### Dataframe to csv

# %%
#Paths donde se guardaran
path30071era5lhN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.1.ERA5_Land/30071era5lhN.csv'
path30160era5lhN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.1.ERA5_Land/30160era5lhN.csv'
path30169era5lhN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.1.ERA5_Land/30169era5lhN.csv'
path30220era5lhN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.1.ERA5_Land/30220era5lhN.csv'
path30304era5lhN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.1.ERA5_Land/30304era5lhN.csv'
path30325era5lhN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.1.ERA5_Land/30325era5lhN.csv'
path30345era5lhN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.1.ERA5_Land/30345era5lhN.csv'

# %%
#Exportando a csv
df_30071era5lhN.to_csv(path30071era5lhN,index=False)
df_30160era5lhN.to_csv(path30160era5lhN,index=False)
df_30169era5lhN.to_csv(path30169era5lhN,index=False)
df_30220era5lhN.to_csv(path30220era5lhN,index=False)
df_30304era5lhN.to_csv(path30304era5lhN,index=False)
df_30325era5lhN.to_csv(path30325era5lhN,index=False)
df_30345era5lhN.to_csv(path30345era5lhN,index=False)

# %% [markdown]
# ## 5.2.-ERA5 Daily Dataset

# %% [markdown]
# ### Paths y Dataframes

# %%
#Dataframes
era5daypath30071 = '/content/drive/MyDrive/ERA5Daily_Est_Dentro/Estacion_30071_era5day.csv'
era5daypath30160 = '/content/drive/MyDrive/ERA5Daily_Est_Dentro/Estacion_30160_era5day.csv'
era5daypath30169 = '/content/drive/MyDrive/ERA5Daily_Est_Dentro/Estacion_30169_era5day.csv'
era5daypath30220 = '/content/drive/MyDrive/ERA5Daily_Est_Dentro/Estacion_30220_era5day.csv'
era5daypath30304 = '/content/drive/MyDrive/ERA5Daily_Est_Dentro/Estacion_30304_era5day.csv'
era5daypath30325 = '/content/drive/MyDrive/ERA5Daily_Est_Dentro/Estacion_30325_era5day.csv'
era5daypath30345 = '/content/drive/MyDrive/ERA5Daily_Est_Dentro/Estacion_30345_era5day.csv'

# %%
#Dataframes
df_30071era5day = pd.read_csv(era5daypath30071)
df_30160era5day = pd.read_csv(era5daypath30160)
df_30169era5day = pd.read_csv(era5daypath30169)
df_30220era5day = pd.read_csv(era5daypath30220)
df_30304era5day = pd.read_csv(era5daypath30304)
df_30325era5day = pd.read_csv(era5daypath30325)
df_30345era5day = pd.read_csv(era5daypath30345)

# %%
df_30071era5day.head()
# Out:
#         fecha       pcp
# 0  1981-01-01  0.000008
# 1  1981-01-02  0.000554
# 2  1981-01-03  0.000000
# 3  1981-01-04  0.000235
# 4  1981-01-05  0.000263

# %% [markdown]
# ### Datetime

# %%
df_30071era5day['fecha'] = pd.to_datetime(df_30071era5day['fecha'])
df_30160era5day['fecha'] = pd.to_datetime(df_30160era5day['fecha'])
df_30169era5day['fecha'] = pd.to_datetime(df_30169era5day['fecha'])
df_30220era5day['fecha'] = pd.to_datetime(df_30220era5day['fecha'])
df_30304era5day['fecha'] = pd.to_datetime(df_30304era5day['fecha'])
df_30325era5day['fecha'] = pd.to_datetime(df_30325era5day['fecha'])
df_30345era5day['fecha'] = pd.to_datetime(df_30345era5day['fecha'])

# %%
df_30071era5day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14426 entries, 0 to 14425
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   14426 non-null  datetime64[ns]
#  1   pcp     14426 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 225.5 KB

# %%
#colocando columna de año_mes
df_30071era5day['año_mes'] = df_30071era5day['fecha'].dt.to_period('M')
df_30160era5day['año_mes'] = df_30160era5day['fecha'].dt.to_period('M')
df_30169era5day['año_mes'] = df_30169era5day['fecha'].dt.to_period('M')
df_30220era5day['año_mes'] = df_30220era5day['fecha'].dt.to_period('M')
df_30304era5day['año_mes'] = df_30304era5day['fecha'].dt.to_period('M')
df_30325era5day['año_mes'] = df_30325era5day['fecha'].dt.to_period('M')
df_30345era5day['año_mes'] = df_30345era5day['fecha'].dt.to_period('M')

# %%
#Colocando columna de pcp en mm
df_30071era5day['pcp_mm'] = df_30071era5day['pcp']*1000
df_30160era5day['pcp_mm'] = df_30160era5day['pcp']*1000
df_30169era5day['pcp_mm'] = df_30169era5day['pcp']*1000
df_30220era5day['pcp_mm'] = df_30220era5day['pcp']*1000
df_30304era5day['pcp_mm'] = df_30304era5day['pcp']*1000
df_30325era5day['pcp_mm'] = df_30325era5day['pcp']*1000
df_30345era5day['pcp_mm'] = df_30345era5day['pcp']*1000

# %%
df_30071era5day.head(15)
# Out:
#         fecha       pcp  año_mes     pcp_mm
# 0  1981-01-01  0.000008  1981-01   0.007587
# 1  1981-01-02  0.000554  1981-01   0.554463
# 2  1981-01-03  0.000000  1981-01   0.000000
# 3  1981-01-04  0.000235  1981-01   0.235325
# 4  1981-01-05  0.000263  1981-01   0.262707
# 5  1981-01-06  0.000024  1981-01   0.023737
# 6  1981-01-07  0.000885  1981-01   0.884593
# 7  1981-01-08  0.000476  1981-01   0.475749
# 8  1981-01-09  0.000555  1981-01   0.554794
# 9  1981-01-10  0.007627  1981-01   7.626658
# 10 1981-01-11  0.003801  1981-01   3.800891
# 11 1981-01-12  0.025735  1981-01  25.735281
# 12 1981-01-13  0.008192  1981-01   8.192272
# 13 1981-01-14  0.000005  1981-01   0.005124
# 14 1981-01-15  0.000282  1981-01   0.281880

# %% [markdown]
# ### Agrupando PCP por mes

# %%
#Agrupando la pcp por mes
df_30071era5dayN = df_30071era5day.groupby('año_mes')['pcp_mm'].sum().reset_index()
df_30160era5dayN = df_30160era5day.groupby('año_mes')['pcp_mm'].sum().reset_index()
df_30169era5dayN = df_30169era5day.groupby('año_mes')['pcp_mm'].sum().reset_index()
df_30220era5dayN = df_30220era5day.groupby('año_mes')['pcp_mm'].sum().reset_index()
df_30304era5dayN = df_30304era5day.groupby('año_mes')['pcp_mm'].sum().reset_index()
df_30325era5dayN = df_30325era5day.groupby('año_mes')['pcp_mm'].sum().reset_index()
df_30345era5dayN = df_30345era5day.groupby('año_mes')['pcp_mm'].sum().reset_index()

# %%
df_30071era5dayN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   año_mes  474 non-null    period[M]
#  1   pcp_mm   474 non-null    float64
# dtypes: float64(1), period[M](1)
# memory usage: 7.5 KB

# %% [markdown]
# ### Dataframe to csv

# %%
#Paths donde se guardaran
path30071era5dayN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.2.ERA5_Daily/30071era5dayN.csv'
path30160era5dayN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.2.ERA5_Daily/30160era5dayN.csv'
path30169era5dayN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.2.ERA5_Daily/30169era5dayN.csv'
path30220era5dayN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.2.ERA5_Daily/30220era5dayN.csv'
path30304era5dayN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.2.ERA5_Daily/30304era5dayN.csv'
path30325era5dayN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.2.ERA5_Daily/30325era5dayN.csv'
path30345era5dayN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.2.ERA5_Daily/30345era5dayN.csv'

# %%
#Exportando a csv
df_30071era5dayN.to_csv(path30071era5dayN, index = False)
df_30160era5dayN.to_csv(path30160era5dayN, index = False)
df_30169era5dayN.to_csv(path30169era5dayN, index = False)
df_30220era5dayN.to_csv(path30220era5dayN, index = False)
df_30304era5dayN.to_csv(path30304era5dayN, index = False)
df_30325era5dayN.to_csv(path30325era5dayN, index = False)
df_30345era5dayN.to_csv(path30345era5dayN, index = False)

# %% [markdown]
# ## 5.3.-ERA5 Montly Dataset

# %% [markdown]
# ### Paths y Dataframe

# %%
#Paths
era5Montpath30071 = '/content/drive/MyDrive/ERA5Montly_Est_Dentro/Estacion_30071_era5mont.csv'
era5Montpath30160 = '/content/drive/MyDrive/ERA5Montly_Est_Dentro/Estacion_30160_era5mont.csv'
era5Montpath30169 = '/content/drive/MyDrive/ERA5Montly_Est_Dentro/Estacion_30169_era5mont.csv'
era5Montpath30220 = '/content/drive/MyDrive/ERA5Montly_Est_Dentro/Estacion_30220_era5mont.csv'
era5Montpath30304 = '/content/drive/MyDrive/ERA5Montly_Est_Dentro/Estacion_30304_era5mont.csv'
era5Montpath30325 = '/content/drive/MyDrive/ERA5Montly_Est_Dentro/Estacion_30325_era5mont.csv'
era5Montpath30345 = '/content/drive/MyDrive/ERA5Montly_Est_Dentro/Estacion_30345_era5mont.csv'

# %%
#Dataframe
df_30071era5mont = pd.read_csv(era5Montpath30071)
df_30160era5mont = pd.read_csv(era5Montpath30160)
df_30169era5mont = pd.read_csv(era5Montpath30169)
df_30220era5mont = pd.read_csv(era5Montpath30220)
df_30304era5mont = pd.read_csv(era5Montpath30304)
df_30325era5mont = pd.read_csv(era5Montpath30325)
df_30345era5mont = pd.read_csv(era5Montpath30345)

# %%
df_30071era5mont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   474 non-null    object
#  1   pcp_m   474 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.5+ KB

# %%
df_30304era5mont.head(15)
# Out:
#       fecha     pcp_m
# 0   1981-01  0.137550
# 1   1981-02  0.038542
# 2   1981-03  0.043739
# 3   1981-04  0.070205
# 4   1981-05  0.099897
# 5   1981-06  0.322538
# 6   1981-07  0.169938
# 7   1981-08  0.232325
# 8   1981-09  0.216304
# 9   1981-10  0.064760
# 10  1981-11  0.023913
# 11  1981-12  0.096097
# 12  1982-01  0.035366
# 13  1982-02  0.044206
# 14  1982-03  0.053681

# %% [markdown]
# ### Datetime

# %%
#df_30071era5mont['fecha'] = pd.to_datetime(df_30071era5mont['fecha'],format='%Y-%M')
#df_30160era5mont['fecha'] = pd.to_datetime(df_30160era5mont['fecha'],format='%Y-%M')
#df_30169era5mont['fecha'] = pd.to_datetime(df_30169era5mont['fecha'],format='%Y-%M')
#df_30220era5mont['fecha'] = pd.to_datetime(df_30220era5mont['fecha'],format='%Y-%M')
#df_30304era5mont['fecha'] = pd.to_datetime(df_30304era5mont['fecha'],format='%Y-%M')
#df_30325era5mont['fecha'] = pd.to_datetime(df_30325era5mont['fecha'],format='%Y-%M')
#df_30345era5mont['fecha'] = pd.to_datetime(df_30345era5mont['fecha'],format='%Y-%M')

# %%
#df_30071era5mont['año_mes'] = df_30071era5mont['fecha'].dt.to_period('M')
#df_30160era5mont['año_mes'] = df_30160era5mont['fecha'].dt.to_period('M')
#df_30169era5mont['año_mes'] = df_30169era5mont['fecha'].dt.to_period('M')
#df_30220era5mont['año_mes'] = df_30220era5mont['fecha'].dt.to_period('M')
#df_30304era5mont['año_mes'] = df_30304era5mont['fecha'].dt.to_period('M')
#df_30325era5mont['año_mes'] = df_30325era5mont['fecha'].dt.to_period('M')
#df_30345era5mont['año_mes'] = df_30345era5mont['fecha'].dt.to_period('M')

# %%
df_30071era5mont.head()
# Out:
#      fecha     pcp_m
# 0  1981-01  0.125772
# 1  1981-02  0.062175
# 2  1981-03  0.054029
# 3  1981-04  0.089828
# 4  1981-05  0.138878

# %%
df_30071era5mont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   474 non-null    object
#  1   pcp_m   474 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.5+ KB

# %%
df_30071era5mont['pcp_mm'] = df_30071era5mont['pcp_m']*1000
df_30160era5mont['pcp_mm'] = df_30160era5mont['pcp_m']*1000
df_30169era5mont['pcp_mm'] = df_30169era5mont['pcp_m']*1000
df_30220era5mont['pcp_mm'] = df_30220era5mont['pcp_m']*1000
df_30304era5mont['pcp_mm'] = df_30304era5mont['pcp_m']*1000
df_30325era5mont['pcp_mm'] = df_30325era5mont['pcp_m']*1000
df_30345era5mont['pcp_mm'] = df_30345era5mont['pcp_m']*1000

# %%
df_30071era5mont.head()
# Out:
#      fecha     pcp_m      pcp_mm
# 0  1981-01  0.125772  125.771537
# 1  1981-02  0.062175   62.175341
# 2  1981-03  0.054029   54.028757
# 3  1981-04  0.089828   89.827672
# 4  1981-05  0.138878  138.878360

# %% [markdown]
# ### Agrupando PCP por mes

# %%
df_30071era5montN = pd.DataFrame({'año_mes':df_30071era5mont['fecha'],'pcp_mm':df_30071era5mont['pcp_mm']})
df_30160era5montN = pd.DataFrame({'año_mes':df_30160era5mont['fecha'],'pcp_mm':df_30160era5mont['pcp_mm']})
df_30169era5montN = pd.DataFrame({'año_mes':df_30169era5mont['fecha'],'pcp_mm':df_30169era5mont['pcp_mm']})
df_30220era5montN = pd.DataFrame({'año_mes':df_30220era5mont['fecha'],'pcp_mm':df_30220era5mont['pcp_mm']})
df_30304era5montN = pd.DataFrame({'año_mes':df_30304era5mont['fecha'],'pcp_mm':df_30304era5mont['pcp_mm']})
df_30325era5montN = pd.DataFrame({'año_mes':df_30325era5mont['fecha'],'pcp_mm':df_30325era5mont['pcp_mm']})
df_30345era5montN = pd.DataFrame({'año_mes':df_30345era5mont['fecha'],'pcp_mm':df_30345era5mont['pcp_mm']})

# %%
df_30071era5montN.head()
# Out:
#    año_mes      pcp_mm
# 0  1981-01  125.771537
# 1  1981-02   62.175341
# 2  1981-03   54.028757
# 3  1981-04   89.827672
# 4  1981-05  138.878360

# %%
df_30071era5montN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   año_mes  474 non-null    object
#  1   pcp_mm   474 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.5+ KB

# %% [markdown]
# ### Dataframe to csv

# %%
#Paths
path30071era5montN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.3.ERA5_Montly/30071era5montN.csv'
path30160era5montN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.3.ERA5_Montly/30160era5montN.csv'
path30169era5montN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.3.ERA5_Montly/30169era5montN.csv'
path30220era5montN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.3.ERA5_Montly/30220era5montN.csv'
path30304era5montN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.3.ERA5_Montly/30304era5montN.csv'
path30325era5montN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.3.ERA5_Montly/30325era5montN.csv'
path30345era5montN = '/content/drive/MyDrive/1.Dataframes_AnalisisdeDatos/5.ERA/5.3.ERA5_Montly/30345era5montN.csv'

# %%
#Exportando
df_30071era5montN.to_csv(path30071era5montN, index=False)
df_30160era5montN.to_csv(path30160era5montN, index=False)
df_30169era5montN.to_csv(path30169era5montN, index=False)
df_30220era5montN.to_csv(path30220era5montN, index=False)
df_30304era5montN.to_csv(path30304era5montN, index=False)
df_30325era5montN.to_csv(path30325era5montN, index=False)
df_30345era5montN.to_csv(path30345era5montN, index=False)

# %% [markdown]
# # 6.-WORLDCLIM
